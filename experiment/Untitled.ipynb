# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
exp = np.loadtxt("2760/dndeta_0_5.dat")
dat = np.loadtxt("/home/xywu/physics/code/clvisc/clvisc2/pyvisc/results/pbpb2760/0_5/event0/dNdEta_mc_charged.dat")

# %%
plt.errorbar(exp[:,0],exp[:,1],yerr=[exp[:,2],exp[:,3]],fmt="o")
plt.plot(dat[:,0],dat[:,1])

# %%
exp = np.loadtxt("5020/exp_5020_dndeta_0_5.dat")
dat = np.loadtxt("/home/xywu/physics/code/clvisc/clvisc2/pyvisc/results/pbpb5020/0_5/event0/dNdEta_mc_charged.dat")

# %%
plt.errorbar(exp[:,0],exp[:,1],yerr=[exp[:,2],exp[:,2]],fmt="o")
plt.plot(dat[:,0],dat[:,1])

# %%
exp = np.loadtxt("5440/0-5dndeta_xexe.dat")
dat = np.loadtxt("/home/xywu/physics/code/clvisc/clvisc2/pyvisc/results/Xe2Xe25440/0_5/event0/dNdEta_mc_charged.dat")

# %%
plt.errorbar(exp[:,0],exp[:,1],yerr=[exp[:,2],exp[:,2]],fmt="o",alpha=0.4)
plt.plot(dat[:,0],dat[:,1])

# %%
exp = np.loadtxt("6500/OO_0_5.dat")
dat = np.loadtxt("/home/xywu/physics/code/clvisc/clvisc2/pyvisc/results/OO6500/0_5/event0/dNdEta_mc_charged.dat")

# %%
plt.errorbar(exp[:,0],exp[:,2],yerr=[exp[:,3],exp[:,3]],fmt="o",alpha=0.4)
plt.plot(dat[:,0],dat[:,1])

# %%
exp = np.loadtxt("5850/ArAr_0_5.dat")
dat = np.loadtxt("/home/xywu/physics/code/clvisc/clvisc2/pyvisc/results/ArAr5850/0_5/event0/dNdEta_mc_charged.dat")

# %%
plt.errorbar(exp[:,0],exp[:,2],yerr=[exp[:,3],exp[:,3]],fmt="o",alpha=0.4)
plt.plot(dat[:,0],dat[:,1])
